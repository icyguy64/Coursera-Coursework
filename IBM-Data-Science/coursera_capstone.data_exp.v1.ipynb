# %% [markdown]
# # Data Exploration Notebook

# %% [markdown]
# In this notebook, we'll perform data exploration

# %% [markdown]
# We import the data into a pandas dataframe.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# Let's do a describe on the dataframe

# %%
df_data_1.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# Let's check for nulls within the pandas dataframe. It's good that there aint any

# %%
df_data_1.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# Let's see what we have in the columns

# %%
df_data_1.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# Let's count the number of rows

# %%
df_data_1['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Wow the dataset is so imbalanced. In this cases, it should be as most transactions are non fraudent. Let's try to visual the dataset.

# %%
import matplotlib.pyplot as plt

allTransactions = pd.value_counts(df_data_1['Class'])
allTransactions.plot(kind='bar', rot=0, figsize=(14,8))
plt.xticks(range(2), ["Normal","Fraud"])
plt.title("Comparison of Fraudulent and non-Fraudulent Transactions")
plt.xlabel("Classification")
plt.ylabel("Total Number of Transactions");

# %% [markdown]
# Try observing the correlation matrix with seaborn heatmap

# %%
import seaborn as sns

corr = df_data_1.corr()
plt = sns.heatmap(corr, cmap='coolwarm_r', annot_kws={'size':20})
plt.set_title("Correlation Matrix ", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix ')

# %% [markdown]
# Try boxplots

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))
colors = ["#0101DF", "#DF0101"]

sns.boxplot(x="Class", y="V17", data=df_data_1, palette=colors, ax=axes[0])
axes[0].set_title('Statistics of Column V17')

sns.boxplot(x="Class", y="V14", data=df_data_1, palette=colors, ax=axes[1])
axes[1].set_title('Statistics of Column V14')


sns.boxplot(x="Class", y="V12", data=df_data_1, palette=colors, ax=axes[2])
axes[2].set_title('Statistics of Column V12')


sns.boxplot(x="Class", y="V10", data=df_data_1, palette=colors, ax=axes[3])
axes[3].set_title('Statistics of Column V10')

plt.show()

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))

# Positive correlations (The higher the feature the probability increases that it will be a fraud transaction)
sns.boxplot(x="Class", y="V11", data=df_data_1, palette=colors, ax=axes[0])
axes[0].set_title('Statistics of Column V11')

sns.boxplot(x="Class", y="V4", data=df_data_1, palette=colors, ax=axes[1])
axes[1].set_title('Statistics of Column V14')


sns.boxplot(x="Class", y="V2", data=df_data_1, palette=colors, ax=axes[2])
axes[2].set_title('Statistics of Column V2')


sns.boxplot(x="Class", y="V19", data=df_data_1, palette=colors, ax=axes[3])
axes[3].set_title('Statistics of Column V19')

plt.show()
